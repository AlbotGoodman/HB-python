# %%
# 
# en variant av deluppgift 1 bara för att få fram listorna. 
# 

import csv

def read_file(x):
    with open(x, 'r', encoding='UTF-8') as file:
        data_list = []
        csv_reader = csv.reader(file, delimiter = ';')
        for rad in csv_reader:
            data_list.append(rad)
        return data_list

file1 = 'livsmedel-1.csv'                                     
livsmedelData = read_file(file1)   

file2 = 'tjänster-1.csv'
tjansteData = read_file(file2)   



import numpy as np
import matplotlib.pyplot as plt

# För att slippa de långa namnen
LD = livsmedelData
TD = tjansteData

# %%
del LD[0]                                    # Ta bort årtalen
del TD[0] 


LDkat = []
TDkat = []
for row in LD:                               # Plocka ut kategorierna och lägg i varsin variabel
    LDkat.append(row[0])
    del row[0]
for row in TD:
    TDkat.append(row[0])
    del row[0]

    
for a in LD:                                 # Gör om data till floats
    for b, c in enumerate(a):
        a[b] = float(c)
for a in TD: 
    for b, c in enumerate(a):
        a[b] = float(c)


LDmax = []                                   # Plocka ut en lista av slutvärdet per rad
TDmax = []
for row in LD:
    LDmax.append(row[len(row)-1])
for row in TD:
    TDmax.append(row[len(row)-1])

    
LDpro = []                                   # Maxvärdet minus originalvärdet för att få ökningen 
TDpro = []
for row in LDmax:
    row = row-100
    LDpro.append(row)
for row in TDmax:
    row = row-100
    TDpro.append(row)

# %%
# Data

kolumn1_1 = 'Kategorier av varor och tjänster'
kolumn1_2 = 'Kategorier av olika typer av livsmedel'
kolumn2 = 'Prisutvecklingen i procentform'
p = '|'


outliner = '+-------------------------------------------------------------------------+'
oneliner = '+-----------------------------------------+-------------------------------+'
twoliner = '+=========================================+===============================+'


# Tabell
# Det borde nog gå att göra en tabell med hjälp av en for-sats
# Sen borde det nog gå att istället för manuellt bestämma ">20" osv att använda len(), t ex: 
#    Om kolumn 1 är X tecken bred

print(outliner)
print(f'{p}{kolumn1_1}{p:>10}{kolumn2}')           
print(twoliner)
print(f'{p}{LDkat[0]}')
print(oneliner)

print(oneliner)

print(oneliner)

print(oneliner)

print(oneliner)

print(oneliner)

print(outliner)

print(outliner)

print(outliner)
print(f'{kolumn1_2}{kolumn2:>34}')
print(twoliner)

print(oneliner)

print(oneliner)

print(oneliner)

print(oneliner)

print(oneliner)

print(oneliner)

print(oneliner)

print(outliner)
# Out:
# +-------------------------------------------------------------------------+
# |Kategorier av varor och tjänster         |Prisutvecklingen i procentform
# +=========================================+===============================+
# |bröd och övriga spannmålsprodukter
# +-----------------------------------------+-------------------------------+
# +-----------------------------------------+-------------------------------+
# +-----------------------------------------+-------------------------------+
# +-----------------------------------------+-------------------------------+
# +-----------------------------------------+-------------------------------+
# +-----------------------------------------+-------------------------------+
# +-------------------------------------------------------------------------+
# +-------------------------------------------------------------------------+
# +-------------------------------------------------------------------------+
# Kategorier av olika typer av livsmedel    Prisutvecklingen i procentform
# +=========================================+===============================+
# +-----------------------------------------+-------------------------------+
# +-----------------------------------------+-------------------------------+
# +-----------------------------------------+-------------------------------+
# +-----------------------------------------+-------------------------------+
# +-----------------------------------------+-------------------------------+
# +-----------------------------------------+-------------------------------+
# +-----------------------------------------+-------------------------------+
# +-------------------------------------------------------------------------+

# %%
print(outliner)
print(f'{kolumn1_1}{kolumn2:>40}')
print(twoliner)

for row in 
print(oneliner)

print(outliner)
